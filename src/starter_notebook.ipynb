# %%
import os
import sys

# If the following line throws an error, do `pip install -e ./` from the base repo dir
from utils import ImageDataset

# Change to match data filepath on local
base_fp = r'/Users/taehun.kim/mids/rendered_256x256/256x256'

# %%
# Example on how to iterate through images
dataset = ImageDataset(base_fp)

for i, group in enumerate(dataset):

    print(f'Image ID {group.id}, Label: {group.label}. \
        {len(group.photos)} photos and {len(group.sketches)} sketches in this group')
# Out:
# Loading dataset...
# Image ID n07739125_2509, Label: apple.         2 photos and 30 sketches in this group
# Image ID n07739125_7934, Label: apple.         2 photos and 30 sketches in this group
# Image ID n07739125_11944, Label: apple.         2 photos and 30 sketches in this group
# Image ID n07739125_14632, Label: apple.         2 photos and 36 sketches in this group
# Image ID n07739125_12041, Label: apple.         2 photos and 36 sketches in this group
# Image ID n07739125_6752, Label: apple.         2 photos and 36 sketches in this group
# Image ID n07739125_3833, Label: apple.         2 photos and 48 sketches in this group
# Image ID n07739125_1229, Label: apple.         2 photos and 36 sketches in this group
# Image ID n07739125_1406, Label: apple.         2 photos and 36 sketches in this group
# Image ID n07739125_6989, Label: apple.         2 photos and 36 sketches in this group
# Image ID n07739125_4181, Label: apple.         2 photos and 36 sketches in this group
# ...

# %%
dataset[0].sketches[0].load()
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...
